# %%
import tweepy
from collections import Counter
import csv
import operator

#getting location of followers

def get_tweets(user_name, number_of_locations) :
    
    consumer_key="xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
    consumer_secret="xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
    access_key="xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
    access_secret="xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api=tweepy.API(auth)

    loci=[]
    
    number_of_tweets=0

    csvFile = open('locations_BurkhaDutt.csv', 'w')
    csvWriter = csv.writer(csvFile)
    dummy=0
    try :
        for tweet in tweepy.Cursor(api.followers, id=user_name).items(number_of_tweets) :
            try :
                info=tweet._json
                location=info['location']
                if location!='' :
                    ind=location.find(',')
                    if ind!=-1 :
                        location=location[:ind]
                    loci.append(location)
                    csvWriter.writerow([location])
                    number_of_tweets+=1
                    print(number_of_tweets)
                    print(location)
                if number_of_tweets==number_of_locations :
                    break
            except Exception as e :
                dummy=0
    except tweepy.error.RateLimitError as f :
            dummy=1
            print("RateLimit")
            csvFile.close()
    if dummy==0 :
        csvFile.close()
    return loci

location_arr=get_tweets('@BDUTT', 200)
# Out:
# 1
# bitragunta
# 2
# Ahmadabad City
# 3
# patna
# 4
# Jhunjhunun
# 5
# Hyderabad
# 6
# Seattle
# 7
# Chicago
# 8
# Arizona
# 9
# Patiala
# 10
# New Delhi
# 11
# Pune
# 12
# Sydney
# 13
# New Delhi
# 14
# Bhubaneswar
# 15
# Kolkata
# 16
# Chennai
# 17
# Mumbai
# 18
# Oddanchatram and Chengannur
# 19
# Srinagar
# 20
# Parsippany
# 21
# Mumbai
# 22
# London
# 23
# Haryana
# 24
# Mumbai
# 25
# Kolkata
# 26
# Pune
# 27
# Bengaluru
# 28
# Vellore
# 29
# Perth
# 30
# apne ghar pe
# 31
# Delhi
# 32
# Nashik
# 33
# Gwalior
# 34
# Al-jubail
# 35
# Churu
# 36
# Mumbai
# 37
# Bengaluru
# 38
# Mumbai
# 39
# Kolkata
# 40
# uncertain
# 41
# Quetta
# 42
# Vibrant Gujarat
# 43
# Sadiqabad
# 44
# USA
# 45
# Washington
# 46
# Delhi
# 47
# Camden Town
# 48
# India
# 49
# India
# 50
# Mumbai
# 51
# Silout
# 52
# Lucknow
# 53
# New Delhi
# 54
# Paris/Swindon
# 55
# mumbai
# 56
# Muzaffarpur
# 57
# New Delhi
# 58
# México
# 59
# Ranchi
# 60
# New Jersey
# 61
# Imaginacionlandia
# 62
# Shevgaon
# 63
# #Hilversum
# 64
# Pune
# 65
# Karachi
# 66
# Singapore
# 67
# Bengaluru South
# 68
# Kolkata
# 69
# Aligarh
# 70
# Ulhasnagar - 3
# 71
# Pakistan
# 72
# Ramayampet
# 73
#  faizabad uttar pardesh
# 74
# Bhubaneswar
# 75
# Derby
# 76
# fgghhh
# 77
# Mumbai
# 78
# Germany
# 79
# Hyderabad
# 80
# Toronto
# 81
# New Delhi
# 82
# India
# 83
# Bhopal
# 84
# Delhi
# 85
# Germany
# 86
# Home
# 87
# Bhopal
# 88
# India
# 89
# Raigarh
# 90
# India
# 91
# India
# 92
# Lucknow
# 93
# Niagara-on-the-Lake
# 94
# Duniya
# 95
# Mumbai
# 96
# Latur
# 97
# Pakistan
# 98
# Bangalore
# RateLimit

# %%
#getting latitudes and longitudes of locations

from geopy.geocoders import Nominatim
nom=Nominatim(user_agent="kiran")
import csv

f=open('locations_RavishKumar.csv', 'r')
read = csv.reader(f)

lat_arr=[]
lon_arr=[]

for line in read :
    if line!=[] :
        place=line[0]
        print(place)
        location=nom.geocode(place)
        try :
            lat=location.latitude
            lon=location.longitude
            lat_arr.append(lat)
            lon_arr.append(lon)
        except AttributeError :
            print('Not done', place)
f.close()

print('done')

# %%
import plotly.express as px
import plotly

fig=px.density_mapbox([],lat=lat_arr, lon=lon_arr, radius=8, mapbox_style='stamen-terrain')
fig.show()
plotly.offline.plot(fig, filename='RavishKumar.html')
# Out:
# <div>                            <div id="df44488d-4d9d-4161-8908-917022a91918" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df44488d-4d9d-4161-8908-917022a91918")) {                    Plotly.newPlot(                        "df44488d-4d9d-4161-8908-917022a91918",                        [{"coloraxis": "coloraxis", "hovertemplate": "lat=%{lat}<br>lon=%{lon}<extra></extra>", "lat": [18.521428, 28.6138954, 23.2584857, 30.2090874, 27.1303344, 22.8176662, 29.538422, 30.7334421, 26.2037247, 25.3356491, 26.718324350000003, 27.639077049999997, 28.6517178, 28.5707841, 26.999697400000002, 27.87698975, 28.42826235, 28.6138954, 22.3511148, 25.6093239, 25.6440845, 28.6517178, 25.8972459, 22.3511148, 19.0759899, 22.3511148, 24.578721, 22.6124961, 28.6138954, 19.0759899, 26.2768118, 19.0759899, 27.1303344, 28.6138954, 25.91331045, 22.7203616, 32.54357545, 24.7964355, 26.67132865, 52.212468, 28.6138954, 22.3850008, 28.6138954, 28.6138954, 25.3356491, 27.662826000000003, 26.8381, 27.1303344, 25.560900349999997, 19.0759899, 24.9001003, 26.1486581, 23.8480899, 24.5, 27.985060150000002, 26.02269675, 20.84351185, 22.7203616, 25.9259562, 26.9154576, 48.6128117, 22.3511148, 12.9791198, 23.2584857, 18.521428, 30.9293211, 23.8902958, 24.819964499999998, 22.3511148, 19.5821138, 30.048095, 31.29201065, 27.1303344, 25.4381302, 18.35146855, 21.75, 19.877263, 16.6931795, 43.4391702, 25.2653471, 30.3663493, 26.1805978, 32.5686782, 22.3511148, 21.1498134, 22.3170513, 23.0216238, 26.8381, 26.9154576, -11.2422264, 12.9791198, 15.5075545, 19.0759899, 26.724789, 27.912633149999998, 22.3511148, 26.8381, -1.3031689499999999, 25.3356491, 19.0759899, 26.1486581, 19.0759899, 28.6138954, 28.6138954, 22.3511148, 31.6343083, 26.242510850000002, 26.8381], "lon": [73.8544541, 77.2090057, 77.401989, 76.3398720856221, 80.859666, 70.8345928, 78.51514669104847, 76.7797143, 78.1573628, 83.0076292, 79.09025375025163, 76.6144524902045, 77.2219388, 77.3271074, 79.68861212775874, 78.13729027600994, 77.00270014657752, 77.2090057, 78.6677428, 85.1235252, 85.906508, 77.2219388, 71.7680892, 78.6677428, 72.8773928, 78.6677428, 73.6862571, 77.762753, 77.2090057, 72.8773928, 86.79658662614811, 72.8773928, 80.859666, 77.2090057, 93.02566787197169, 75.8681996, 75.94484088677805, 85.0079563, 83.36458284327038, 0.1037587, 77.2090057, 71.7452633, 77.2090057, 77.2090057, 83.0076292, 75.02792628691331, 80.9346001, 80.859666, 87.64765353997149, 72.8773928, 84.0182110684575, 85.34001282479626, 77.941471, 81.0, 80.75384538357649, 83.02887343114848, 75.52592658756026, 75.8681996, 86.82042961035677, 75.8189817, 7.5948011, 78.6677428, 77.5912997, 77.401989, 73.8544541, 75.5004841, 87.5310132, 92.49167641087158, 78.6677428, 74.4709449, 76.3338623, 75.56805772253911, 80.859666, 81.8338005, 76.7551212230513, 73.0, 75.3390241, 78.9147252, -1.5898909, 55.2924914, 76.82004830848476, 91.753943, 74.071481, 78.6677428, 79.0820556, -79.0745285, 72.5797068, 80.9346001, 75.8189817, 132.1804419, 77.5912997, 80.06080046754784, 72.8773928, 82.79326865024002, 79.74656294869826, 78.6677428, 80.9346001, 36.826061224105075, 83.0076292, 72.8773928, 85.34001282479626, 72.8773928, 77.2090057, 77.2090057, 78.6677428, 74.8736788, 82.29616931685918, 80.9346001], "name": "", "radius": 8, "subplot": "mapbox", "type": "densitymapbox"}],                        {"coloraxis": {"colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "mapbox": {"center": {"lat": 24.993816247222224, "lon": 75.00269887338533}, ...
# 'RavishKumar.html'
